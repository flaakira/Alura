# %% [markdown]
# <a href="https://colab.research.google.com/github/flaakira/Alura/blob/master/Customizacao_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Biblioteca usada

# %% [markdown]
# Biblioteca
#   - Pandas
#     - datetime
#     - groupby
#     - read
#     - rename
#     - for
#   - Matplotlib
#     - plot
#     - bar
#     - pie
#     - scatter
#     - xticklabels
#     - hist
#
#   - Pil - Image
#     - map
#     - open

# %% [markdown]
# # Aula 1

# %% [markdown]
# Fazendo primeiras visualizacoes

# %%
import pandas as pd

# %%
df = pd.read_csv('monitoramento_tempo.csv')

# %%
df.head(5)
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15,6))
plt.plot(df['data'], df['temperatura'])
plt.title('Temperatura no tempo')
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %%
fig = plt.figure(figsize=(15,6))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'lightgreen')

eixo.set_title('Temperatura no momento', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower left', fontsize = 15)

# %% [markdown]
# # Aula 2

# %% [markdown]
# Customizando nossas visualizacoes

# %%
fig = plt.figure(figsize=(15,6))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'darkgreen', ls = 'dotted', lw = 2, marker = '.')

eixo.set_title('Temperatura no momento', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower left', fontsize = 15)

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,6))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'yellow')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower left', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(15,6))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color = 'yellow')

eixo.set_xlim(datetime.datetime(2015,1,1), datetime.datetime(2016,1,1))
eixo.set_title('Temperatura no momento', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower left', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(15,6))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.65,0.3,0.3])
eixo3 = fig.add_axes([0.65,0.65,0.3,0.3])
eixo4 = fig.add_axes([0.1,0.1,0.3,0.3])
eixo5 = fig.add_axes([0.65,0.1,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'grey')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

eixo2.grid(True)
eixo2.set_xlim(datetime.datetime(2013,1,1), datetime.datetime(2014,1,1))
eixo2.plot(df['data'], df['temperatura'], color = 'blue')
eixo2.set_title('Temperatura em 2013', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'lower center', fontsize = 8)

eixo3.grid(True)
eixo3.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo3.plot(df['data'], df['temperatura'], color = 'green')
eixo3.set_title('Temperatura em 2014', fontsize = 15)
eixo3.legend(['Temperatura'], loc = 'lower center', fontsize = 8)

eixo4.grid(True)
eixo4.set_xlim(datetime.datetime(2015,1,1), datetime.datetime(2016,1,1))
eixo4.plot(df['data'], df['temperatura'], color = 'red')
eixo4.set_title('Temperatura em 2015', fontsize = 15)
eixo4.legend(['Temperatura'], loc = 'lower center', fontsize = 8)

eixo5.grid(True)
eixo5.set_xlim(datetime.datetime(2016,1,1), datetime.datetime(2017,1,1))
eixo5.plot(df['data'], df['temperatura'], color = 'yellow')
eixo5.set_title('Temperatura em 2016', fontsize = 15)
eixo5.legend(['Temperatura'], loc = 'lower center', fontsize = 8)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em maio/2014', fontsize = 25, pad = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)

eixo2.grid(True)
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color ='b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color ='b')
eixo2.plot(df['data'], df['temperatura'], color = 'g')
eixo2.set_title('Temperatura em 2014', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'lower center', fontsize = 8)

# %% [markdown]
# # Aula 3

# %% [markdown]
#  Anotações e diversos gráficos

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc='lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() -7000]
y2 = max(df['temperatura']-5)

eixo.annotate("Maximo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'k', linestyle= '--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle= '--')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc='lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() -7000]
y2 = min(df['temperatura']+5)

eixo.annotate("Minimo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'k', linestyle= '--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle= '--')

# %%
 fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc='lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() -7000]
y2 = max(df['temperatura']-5)

eixo.annotate("Maximo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

x1 = df['data'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() -7000]
y2 = min(df['temperatura']+5)

eixo.annotate("Minimo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'k', linestyle= '--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle= '--')

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça','Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['k','r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color= cores, edgecolor = 'k')
eixo.set_title('Temperatura por dia da semana', fontsize = 25)
eixo.set_ylabel('Dia da semana', fontsize = 20)
eixo.set_xlabel('Temperatura media', fontsize = 20)  
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.2,0,0,0,0,0.2,0.2]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index, 
         autopct='%0.3f%%', explode = explodir, shadow=True)
eixo.set_title('Temperatura por dia da semana', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# # Aula 4

# %% [markdown]
# Visualizando dados diferentes

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_iris = pd.read_csv('iris.csv')
df_iris.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
renomar = {'comprimento_sépala' : 'comprimento_sepala',
           'largura_sépala'	: 'largura_sepala',
           'comprimento_pétala'	:'comprimento_petala',
           'largura_pétala'	: 'largula_petala',
           'espécie': 'especie'}

# %%
df_iris = df_iris.rename(columns = renomar)
df_iris
# Out:
#      comprimento_sepala  largura_sepala  ...  largula_petala         especie
# 0                   5.1             3.5  ...             0.2     Iris-setosa
# 1                   4.9             3.0  ...             0.2     Iris-setosa
# 2                   4.7             3.2  ...             0.2     Iris-setosa
# 3                   4.6             3.1  ...             0.2     Iris-setosa
# 4                   5.0             3.6  ...             0.2     Iris-setosa
# ..                  ...             ...  ...             ...             ...
# 145                 6.7             3.0  ...             2.3  Iris-virginica
# 146                 6.3             2.5  ...             1.9  Iris-virginica
# 147                 6.5             3.0  ...             2.0  Iris-virginica
# 148                 6.2             3.4  ...             2.3  Iris-virginica
# 149                 5.9             3.0  ...             1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'v', 'Iris-virginica': 'o'}

for especie in df_iris['especie'].unique():
  tmp = df_iris[df_iris['especie'] == especie]
  eixo.scatter(tmp['comprimento_sepala'], tmp['largura_sepala'], 
               color=cores[especie], marker=marcadores[especie], s=100)

eixo.set_title('Grafico de dispersao', fontsize = 25, pad=15)
eixo.set_xlabel('Comprimento da sepala', fontsize=15)
eixo.set_ylabel('Largura da sepala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores,fontsize=20)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df_iris.drop('especie', axis=1).values, patch_artist=True)
eixo.set_title('Grafico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df_iris.drop('especie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color=cor)

for outlier in caixas['fliers']:
  outlier.set(marker='x', markersize=8)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df_iris['comprimento_petala'],bins=20, density=True)
eixo.set_title('Histograma', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

# %% [markdown]
# # Aula 5

# %% [markdown]
# Customizando Histogramas

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df_iris['comprimento_petala'].mean(), df_iris['comprimento_petala'].std()

eixo.hist(df_iris['comprimento_petala'],bins=20)
eixo.set_title('Histograma', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu,sigma), 
              xy=(4.5,20), fontsize=20)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df_iris['comprimento_petala'].mean(), df_iris['comprimento_petala'].std()

eixo.hist(df_iris['comprimento_petala'],bins=20)
eixo.set_title('Histograma', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), 
              xy=(4.5,20), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('media', xy=(mu-1.3,28), fontsize=20)

eixo.axvline(df_iris['comprimento_petala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_iris['comprimento_petala'].median(), 31),fontsize=20)
# Out:
# Text(4.35, 31, 'mediana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_iv = df_iris[df_iris['especie']== 'Iris-versicolor']

mu, sigma = df_iv['comprimento_petala'].mean(), df_iv['comprimento_petala'].std()

eixo.hist(df_iv['comprimento_petala'],bins=20)
eixo.set_title('Iris - versicolor', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), 
              xy=(4.6,6), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('media', xy=(mu -0.5,5.5), fontsize=20)

eixo.axvline(df_iv['comprimento_petala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_iv['comprimento_petala'].median()
                             -0.7,6.5),fontsize=20, color = 'g')

fig.savefig('Histograma_iv.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = df_iris[df_iris['especie']== 'Iris-setosa']

mu, sigma = df_is['comprimento_petala'].mean(), df_is['comprimento_petala'].std()

eixo.hist(df_is['comprimento_petala'],bins=20)
eixo.set_title('Iris - Setosa', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), 
              xy=(1.7,7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('media', xy=(mu -0.2,13.5), fontsize=20)

eixo.axvline(df_is['comprimento_petala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_is['comprimento_petala'].median()+0.05,12),fontsize=20, color = 'g')

fig.savefig('Histograma_is.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_ivc = df_iris[df_iris['especie']== 'Iris-virginica']

mu, sigma = df_ivc['comprimento_petala'].mean(), df_ivc['comprimento_petala'].std()

eixo.hist(df_ivc['comprimento_petala'],bins=20)
eixo.set_title('Iris - Virginica', fontsize= 15, pad=10)
eixo.set_xlabel('Comprimento da petala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu,sigma), 
              xy=(6.3,7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('media', xy=(mu, 8), fontsize=20)

eixo.axvline(df_ivc['comprimento_petala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_ivc['comprimento_petala'].median(),
                             7),fontsize=20, color = 'g')

fig.savefig('Histograma_ivg.png', bbox_inches='tight')

# %%
from PIL import Image

largura, altura = Image.open('Histograma_ivg.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['Histograma_iv.png', 'Histograma_is.png', 'Histograma_ivg.png']):
  combinada.paste(imagem, (intervalo,0))
  intervalo += largura

combinada.save('combinado.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1176x360 at 0x7F624BEEA278>
